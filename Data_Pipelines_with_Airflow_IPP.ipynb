# %% [markdown]
# <a href="https://colab.research.google.com/github/WKhisa/Data-Pipelines-with-Airflow/blob/main/Data_Pipelines_with_Airflow_IPP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
customer_data_df = pd.read_csv('https://raw.githubusercontent.com/WKhisa/Data-Pipelines-with-Airflow/main/customer_data.csv')
order_data_df = pd.read_csv('https://raw.githubusercontent.com/WKhisa/Data-Pipelines-with-Airflow/main/order_data.csv')
order_data_df = pd.read_csv('https://raw.githubusercontent.com/WKhisa/Data-Pipelines-with-Airflow/main/payment_data.csv')
# Out:
#    customer_id first_name last_name                        email   country  \
# 0            1       John       Doe         john.doe@example.com       USA
# 1            2       Jane     Smith       jane.smith@example.com       USA
# 2            3       Paul    Mukasa      paul.mukasa@example.com    Rwanda
# 3            4      Grace     Uwase      grace.uwase@example.com    Rwanda
# 4            5   Emmanuel    Mukiza  emmanuel.mukiza@example.com    Rwanda
# 5            6     Angela   Mirembe   angela.mirembe@example.com    Uganda
# 6            7     Joseph   Ndung'u    joseph.ndungu@example.com     Kenya
# 7            8     Esther    Kimani    esther.kimani@example.com     Kenya
# 8            9      David    Mwanza     david.mwanza@example.com  Tanzania
# 9           10      Fatma      Said       fatma.said@example.com  Tanzania
#
#    gender date_of_birth
# 0    Male    1990-01-01
# 1  Female    1992-05-12
# 2    Male    1985-07-28
# 3  Female    1995-12-31
# ...

# %%
order_data_df = pd.read_csv('https://raw.githubusercontent.com/WKhisa/Data-Pipelines-with-Airflow/main/order_data.csv')
order_data_df = pd.read_csv('https://raw.githubusercontent.com/WKhisa/Data-Pipelines-with-Airflow/main/payment_data.csv')
